# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('AirQuality.csv', sep=";")

# %%
df1
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9  \
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)
# 0            1046.0    166.0        1056.0    113.0        1692.0  \
# ...

# %%
df2=pd.read_csv('heart.csv')

# %%
df2
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#data cleaning
df1.isnull().sum()
droped_df1=df1.dropna()

# %%
droped_df1.isnull().sum()
# Out:
# Date             0.0
# Time             0.0
# CO(GT)           0.0
# PT08.S1(CO)      0.0
# NMHC(GT)         0.0
# C6H6(GT)         0.0
# PT08.S2(NMHC)    0.0
# NOx(GT)          0.0
# PT08.S3(NOx)     0.0
# NO2(GT)          0.0
# PT08.S4(NO2)     0.0
# PT08.S5(O3)      0.0
# T                0.0
# RH               0.0
# AH               0.0
# Unnamed: 15      0.0
# Unnamed: 16      0.0
# dtype: float64

# %%
cleaned_df2=df2.isnull().sum()
cleaned_df2
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#data integration
df3=df2[['age','sex','trestbps','chol']].loc[0:20]
df3
# Out:
#     age  sex  trestbps  chol
# 0    52    1       125   212
# 1    53    1       140   203
# 2    70    1       145   174
# 3    61    1       148   203
# 4    62    0       138   294
# 5    58    0       100   248
# 6    58    1       114   318
# 7    55    1       160   289
# 8    46    1       120   249
# 9    54    1       122   286
# 10   71    0       112   149
# 11   43    0       132   341
# 12   34    0       118   210
# 13   51    1       140   298
# 14   52    1       128   204
# 15   34    0       118   210
# 16   51    0       140   308
# 17   54    1       124   266
# 18   50    0       120   244
# 19   58    1       140   211
# 20   60    1       140   185

# %%
df4=df2[['age','sex','trestbps','chol']].loc[21:40]
df4
# Out:
#     age  sex  trestbps  chol
# 21   67    0       106   223
# 22   45    1       104   208
# 23   63    0       135   252
# 24   42    0       120   209
# 25   61    0       145   307
# 26   44    1       130   233
# 27   58    0       136   319
# 28   56    1       130   256
# 29   55    0       180   327
# 30   44    1       120   169
# 31   50    0       120   244
# 32   57    1       130   131
# 33   70    1       160   269
# 34   50    1       129   196
# 35   46    1       150   231
# 36   51    1       125   213
# 37   59    1       138   271
# 38   64    1       128   263
# 39   57    1       128   229
# 40   65    0       160   360

# %%
integrated_df=pd.concat([df3,df4])
integrated_df
# Out:
#     age  sex  trestbps  chol
# 0    52    1       125   212
# 1    53    1       140   203
# 2    70    1       145   174
# 3    61    1       148   203
# 4    62    0       138   294
# 5    58    0       100   248
# 6    58    1       114   318
# 7    55    1       160   289
# 8    46    1       120   249
# 9    54    1       122   286
# 10   71    0       112   149
# 11   43    0       132   341
# 12   34    0       118   210
# 13   51    1       140   298
# 14   52    1       128   204
# 15   34    0       118   210
# 16   51    0       140   308
# 17   54    1       124   266
# 18   50    0       120   244
# 19   58    1       140   211
# 20   60    1       140   185
# 21   67    0       106   223
# 22   45    1       104   208
# 23   63    0       135   252
# 24   42    0       120   209
# 25   61    0       145   307
# 26   44    1       130   233
# 27   58    0       136   319
# 28   56    1       130   256
# 29   55    0       180   327
# 30   44    1       120   169
# ...

# %%
#data transformation

# %%
df2.loc[df2['sex']==1, 'sex']='M'

# %%
df2.loc[df2['sex']==0, 'sex']='F'

# %%
df2.head()
# Out:
#    age sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0   52   M   0       125   212    0        1      168      0      1.0      2  \
# 1   53   M   0       140   203    1        0      155      1      3.1      0
# 2   70   M   0       145   174    0        1      125      1      2.6      0
# 3   61   M   0       148   203    0        1      161      0      0.0      2
# 4   62   F   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df2['sex']=labelencoder.fit_transform(df2['sex'])
df2
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df1["Date"]=pd.to_datetime(df1["Date"],format='mixed')
df1.replace(to_replace=',',value='.',inplace=True)
df1
# Out:
#            Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)
# 0    2004-10-03  18.00.00    2.6       1360.0     150.0     11.9  \
# 1    2004-10-03  19.00.00      2       1292.0     112.0      9.4
# 2    2004-10-03  20.00.00    2.2       1402.0      88.0      9.0
# 3    2004-10-03  21.00.00    2.2       1376.0      80.0      9.2
# 4    2004-10-03  22.00.00    1.6       1272.0      51.0      6.5
# ...         ...       ...    ...          ...       ...      ...
# 9466        NaT       NaN    NaN          NaN       NaN      NaN
# 9467        NaT       NaN    NaN          NaN       NaN      NaN
# 9468        NaT       NaN    NaN          NaN       NaN      NaN
# 9469        NaT       NaN    NaN          NaN       NaN      NaN
# 9470        NaT       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)
# 0            1046.0    166.0        1056.0    113.0        1692.0  \
# ...

# %%
df1.head()

# %%
#error correction

# %%
df2[df2['ca']==4]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 52    38    1   2       138   175    0        1      173      0      0.0  \
# 83    38    1   2       138   175    0        1      173      0      0.0
# 128   52    1   2       138   223    0        1      169      0      0.0
# 208   38    1   2       138   175    0        1      173      0      0.0
# 242   38    1   2       138   175    0        1      173      0      0.0
# 290   52    1   2       138   223    0        1      169      0      0.0
# 340   38    1   2       138   175    0        1      173      0      0.0
# 348   43    1   0       132   247    1        0      143      1      0.1
# 417   52    1   2       138   223    0        1      169      0      0.0
# 428   43    1   0       132   247    1        0      143      1      0.1
# 465   38    1   2       138   175    0        1      173      0      0.0
# 521   58    1   1       125   220    0        1      144      0      0.4
# ...

# %%
df2.loc[df2['ca']==4,'ca']=np.NaN
df2=df2.fillna(df2.median())

# %%
df2.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df2
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope   ca  thal  target
# 0         2  2.0     3       0
# ...

# %%
#model building

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(df2.iloc[:,:-1],df2.iloc[:,-1], test_size=0.2, random_state=0)
x_train.shape,x_test.shape,y_train.shape
# Out:
# ((820, 13), (205, 13), (820,))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 0.77081683,  0.65317632, -0.16532734,  0.8755129 , -0.02339703,
#         0.0582165 ,  0.26970753, -0.08840409,  0.06798212,  0.59526434,
#         0.4744177 , -0.45294461,  0.64018179,  0.53768008,  0.83572045,
#         1.01681343,  0.99654961, -0.1927175 ,  1.10340338,  0.30245842,
#         0.84137997,  0.79952724,  0.67463127,  0.79952724,  1.01681343,
#         0.92145672,  0.99711026,  0.67721254,  1.13651832,  1.13034067,
#         1.11344881, -0.08840409,  0.08839364,  0.69351311,  0.36639239,
#        -0.22783399,  0.55726444,  0.43290095,  0.6930733 ,  0.73872441,
#         0.91318853,  0.71300579,  0.9202736 ,  0.97643168,  0.93426088,
#         0.94481702,  0.8842656 ,  0.68633632, -0.21779696,  0.64721837,
#         0.4467995 ,  0.09737353,  0.55324067,  0.56408904, -0.14722955,
#         0.20358361, -0.09808844,  0.72362562, -0.18802999,  0.65317632,
#         0.41890533,  0.54292094,  0.9579809 ,  0.57845402,  0.44414668,
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 0.5822539042718631

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
rmse
# Out:
# 0.32285481327281834
